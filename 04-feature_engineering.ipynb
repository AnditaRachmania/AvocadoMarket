# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
raw = pd.read_csv('./data_csv/updated_city_region.csv', index_col=0)

# %%
raw
# Out:
#        average_price  total_volume       4046       4225      4770  \
# 0               1.22      40873.28    2819.50   28287.42     49.90
# 1               1.79       1373.95      57.42     153.88      0.00
# 2               1.00     435021.49  364302.39   23821.16     82.15
# 3               1.76       3846.69    1500.15     938.35      0.00
# 4               1.08     788025.06   53987.31  552906.04  39995.03
# ...              ...           ...        ...        ...       ...
# 30012           1.63       1798.00     249.00     143.00      0.00
# 30013           1.12     591420.66  238039.66   16379.48    151.06
# 30014           1.19      14134.00     200.00       0.00      0.00
# 30019           0.89    1240709.05  430203.10  126497.28  21104.42
# 30020           1.58      36881.00    1147.00    1243.00   2645.00
#
#        total_bags  small_bags  large_bags  xlarge_bags          type  year  \
# 0         9716.46     9186.93      529.53         0.00  conventional  2015
# ...

# %% [markdown]
# Dari feature selection, selected feature:
# - year
# - month
# - type
# - total_volume
# - city

# %%
df = raw[['year', 'month', 'type', 'total_volume', 'city', 'average_price']]

# %%
df['total_volume'].describe()
# Out:
# count    2.668500e+04
# mean     3.854724e+05
# std      8.538627e+05
# min      8.456000e+01
# 25%      1.217000e+04
# 50%      9.168796e+04
# 75%      3.912570e+05
# max      1.132468e+07
# Name: total_volume, dtype: float64

# %%
bins = [84, 12170, 91688, 391257, 11324683]
labels = ['small', 'medium', 'large', 'wholesale']

# %%
df['category_vol'] = pd.cut(df['total_volume'], bins=bins, labels=labels)

# %%
df
# Out:
#        year    month          type  total_volume                  city  \
# 0      2015  January  conventional      40873.28                Albany
# 1      2015  January       organic       1373.95                Albany
# 2      2015  January  conventional     435021.49               Atlanta
# 3      2015  January       organic       3846.69               Atlanta
# 4      2015  January  conventional     788025.06  Baltimore/Washington
# ...     ...      ...           ...           ...                   ...
# 30012  2020      May       organic       1798.00              Syracuse
# 30013  2020      May  conventional     591420.66                 Tampa
# 30014  2020      May       organic      14134.00                 Tampa
# 30019  2020      May  conventional    1240709.05   West Tex/New Mexico
# 30020  2020      May       organic      36881.00   West Tex/New Mexico
#
#        average_price category_vol
# 0               1.22       medium
# 1               1.79        small
# ...

# %%
df['category_vol'].value_counts()
# Out:
# wholesale    6672
# small        6672
# medium       6671
# large        6670
# Name: category_vol, dtype: int64

# %%
## pengecekan jumlah baris setelah dibinning

6672+6672+6671+6670
# Out:
# 26685

# %%
df.drop(columns=['total_volume'], inplace=True)

# %%
df.head()
# Out:
#    year    month          type                  city  average_price  \
# 0  2015  January  conventional                Albany           1.22
# 1  2015  January       organic                Albany           1.79
# 2  2015  January  conventional               Atlanta           1.00
# 3  2015  January       organic               Atlanta           1.76
# 4  2015  January  conventional  Baltimore/Washington           1.08
#
#   category_vol
# 0       medium
# 1        small
# 2    wholesale
# 3        small
# 4    wholesale

# %%
# df.to_csv('./data_csv/binned.csv')

# %%
# df.to_excel('./data_csv/selected.xlsx')
